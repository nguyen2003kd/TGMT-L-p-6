# %%
import numpy as np
from PIL import Image

def average_images(image_list):
    total_array = np.array(Image.open(image_list[0]), 'f')
    count=1

    for image_path in image_list[1:]:
        try:
            image_array = np.array(Image.open(image_path), 'f')
            total_array += image_array
            count=count+1
        except:
            print("Skip ", image_path);

    # Tính trung bình
    average_array = total_array / count

    # Chuyển đổi kết quả trung bình thành hình ảnh
    average_image = Image.fromarray(average_array.astype('uint8'))

    return average_image

# %%
img_path_1 = 'C:/Users/vudin/OneDrive/Hình ảnh/Saved Pictures/download.jfif'
img_path_2 = 'C:/Users/vudin/OneDrive/Hình ảnh/Saved Pictures/download4.jfif'
image_list = [img_path_1, img_path_2]
result_image = average_images(image_list)
display(result_image)
# Out:
# Skip  C:/Users/vudin/OneDrive/Hình ảnh/Saved Pictures/download4.jfif
# <PIL.Image.Image image mode=RGB size=225x225>

# %%
img_path_1 = 'C:/Users/vudin/OneDrive/Hình ảnh/Saved Pictures/download1.jpg'
img_path_2 = 'C:/Users/vudin/OneDrive/Hình ảnh/Saved Pictures/download2.jpg'
image_list = [img_path_1, img_path_2]
result_image = average_images(image_list)
display(result_image)
# Out:
# <PIL.Image.Image image mode=RGB size=148x148>
