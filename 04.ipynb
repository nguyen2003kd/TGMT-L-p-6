# %%
from PIL import Image
from imgtools import *

# %%
dir = 'C:/Users/vudin/OneDrive/Hình ảnh/Saved Pictures/download.jfif'

# %%
img = load_image(dir)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225>

# %%
region = (100, 75, 175, 160)

# %%
cropped_image = img.crop(region)

# %%
display(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGB size=75x85>

# %%
paste_position = (150, 70)

# %%
img.paste(cropped_image, paste_position)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225>

# %%
rotate=img.rotate(90)

# %%
display(rotate)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>

# %%
transposed=img.transpose(Image.Transpose.ROTATE_90)

# %%
display(transposed)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>

# %%
gray_image = img.convert("L")
display(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=225x225>

# %%
red_band, green_band, blue_band = img.split()
display(red_band)
display(green_band)
display(blue_band)
# Out:
# <PIL.Image.Image image mode=L size=225x225>
# <PIL.Image.Image image mode=L size=225x225>
# <PIL.Image.Image image mode=L size=225x225>
