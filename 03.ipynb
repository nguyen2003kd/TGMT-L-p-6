# %%
from PIL import Image

# %%
dir = 'C:/Users/vudin/OneDrive/Hình ảnh/Saved Pictures/Capture2.PNG'

# %%
image_path = dir

# %%
img01 = Image.open(image_path)

# %%
display(img01)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=783x418>

# %%
new_size = (50,50)

# %%
new_image = img01.resize(new_size)

# %%
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=50x50>
