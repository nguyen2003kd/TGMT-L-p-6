# %%
from PIL import Image
from imgtools import *

# %%
mydir = 'C:/Users/vudin/OneDrive/Hình ảnh/Saved Pictures'

# %%
imgs =  get_image_list(mydir)

# %%
for img in imgs:
    print(img.size)
    display(img)
# Out:
# (830, 439)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=830x439>
# (824, 393)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=824x393>
# (835, 382)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=835x382>
# (761, 428)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=761x428>
# (819, 390)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=819x390>
# (829, 371)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=829x371>
# (740, 422)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=740x422>
# (823, 288)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=823x288>
# (783, 418)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=783x418>
# (833, 416)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=833x416>
# (834, 443)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=834x443>
# (824, 407)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=824x407>
# (830, 446)
# ...
